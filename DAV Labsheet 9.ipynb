# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('stock_data.csv',parse_dates=True,index_col="Date")

# %%
df.head()
# Out:
#              Open   High    Low  Close    Volume  Name
# Date
# 2006-01-03  39.69  41.22  38.79  40.91  24232729  AABA
# 2006-01-04  41.22  41.90  40.77  40.97  20553479  AABA
# 2006-01-05  40.93  41.73  40.85  41.53  12829610  AABA
# 2006-01-06  42.88  43.57  42.80  43.21  29422828  AABA
# 2006-01-09  43.10  43.66  42.82  43.42  16268338  AABA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2263 entries, 2006-01-03 to 2014-12-30
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    2263 non-null   float64
#  1   High    2263 non-null   float64
#  2   Low     2263 non-null   float64
#  3   Close   2263 non-null   float64
#  4   Volume  2263 non-null   int64
#  5   Name    2263 non-null   object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 123.8+ KB

# %%
df.isnull()
# Out:
#              Open   High    Low  Close  Volume   Name
# Date
# 2006-01-03  False  False  False  False   False  False
# 2006-01-04  False  False  False  False   False  False
# 2006-01-05  False  False  False  False   False  False
# 2006-01-06  False  False  False  False   False  False
# 2006-01-09  False  False  False  False   False  False
# ...           ...    ...    ...    ...     ...    ...
# 2014-12-23  False  False  False  False   False  False
# 2014-12-24  False  False  False  False   False  False
# 2014-12-26  False  False  False  False   False  False
# 2014-12-29  False  False  False  False   False  False
# 2014-12-30  False  False  False  False   False  False
#
# [2263 rows x 6 columns]

# %%
df.isna().count()
# Out:
# Open      2263
# High      2263
# Low       2263
# Close     2263
# Volume    2263
# Name      2263
# dtype: int64

# %%
#deleting column
df.drop(columns='Unnamed:0')
#If you get an aerror thats means the code is working properly and there is no column with the name Unnamed
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /workspaces/DAV-Python/DAV Labsheet 9.ipynb Cell 7 line 2
#       <a href='vscode-notebook-cell://codespaces%2Bautomatic-acorn-jvpw4rj794v35qx5/workspaces/DAV-Python/DAV%20Labsheet%209.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> #deleting column
# ----> <a href='vscode-notebook-cell://codespaces%2Bautomatic-acorn-jvpw4rj794v35qx5/workspaces/DAV-Python/DAV%20Labsheet%209.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> df.drop(columns='Unnamed:0')
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
# ...

# %%
df['Volume'].plot(title='What is this graph???',xlabel='Year',ylabel='Volume')
# Out:
# <Axes: title={'center': 'What is this graph???'}, xlabel='Year', ylabel='Volume'>

# %%
df['Low'].plot(title='What is this graph???',xlabel='Year',ylabel='Low')
# Out:
# <Axes: title={'center': 'What is this graph???'}, xlabel='Year', ylabel='Low'>

# %%
df['High'].plot(title='What is this graph???',xlabel='Year',ylabel='High')
# Out:
# <Axes: title={'center': 'What is this graph???'}, xlabel='Year', ylabel='High'>

# %%
df.plot(subplots=True,figsize=(10,12),title="Something")
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
#Resampling the time series data vased on monthly 'M' frequency
df_month = df.resample("M").mean()

#Using subplot
fig, ax = plt.subplots(figsize=(10,6))

#Plotting the bar graph
ax.bar(df_month['2016':].index,df_month.loc['2016':, "Volume"], width=25, align='center')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# --> 871     res = func(group)
#     872     res = extract_result(res)
# ...

# %%
df.Low.diff(2).plot(figsize=(10,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df.High.diff(2).plot(figsize=(10,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df.Close.diff(2).plot(figsize=(10,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df.Volume.diff(2).plot(figsize=(10,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# PLOTTING CHANGES IN DATA. IT CAN BE DONE THROUGH MANY WAYS
#
# 1.SHIFT : THIS FUNCTION CAN BE SUED TO SHIFT THE DATA BEFORE OR AFTER THE SPECIFIES TIME INTERVAL. WE CAN SEPCIFY THE TIME AND IT WILL SHIFT THE DATA ONE DAY BY DEFAULT.
# 2.

# %%
df['Change']=df.Close.div(df.Close.shift())
df['Change'].plot(figsize=(10,8),fontsize=16)
plt.title("Changing the day by day value")
# Out:
# Text(0.5, 1.0, 'Changing the day by day value')

# %%
df['2007':]['Change'].plot(figsize=(10,6))
# Out:
# <Axes: xlabel='Date'>
