# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %% [markdown]
# Generating 10 random numbers between 25 to 35

# %%
age=[random.randrange(25,35,1) for ages in range(11)]
ages=sorted(age,reverse=False)
print("Unsorted",age)
print("Sorted",ages)
# Out:
# Unsorted [30, 33, 26, 26, 29, 26, 28, 32, 34, 25, 31]
# Sorted [25, 26, 26, 26, 28, 29, 30, 31, 32, 33, 34]

# %% [markdown]
# Generating 10 random numbers between 30k to 45k

# %%
dev=[random.randrange(30000,45000,1) for ages in range(11)]
devs=sorted(dev,reverse=True)
print("Unsorted",dev)
print("Sorted",devs)
# Out:
# Unsorted [40294, 33148, 36115, 36137, 35004, 30399, 31407, 43970, 41543, 39798, 39643]
# Sorted [43970, 41543, 40294, 39798, 39643, 36137, 36115, 35004, 33148, 31407, 30399]

# %% [markdown]
# PLotting the Line Graph

# %%
plt.plot(ages,devs)
plt.show()
