# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %% [markdown]
# Generating 10 random numbers between 25 to 35

# %%
age=[random.randrange(25,35,1) for ages in range(11)]
ages=sorted(age,reverse=False)
print("Unsorted",age)
print("Sorted",ages)
# Out:
# Unsorted [34, 34, 25, 27, 30, 26, 33, 33, 30, 33, 34]
# Sorted [25, 26, 27, 30, 30, 33, 33, 33, 34, 34, 34]

# %% [markdown]
# Generating 10 random numbers between 30k to 45k

# %%
dev=[random.randrange(30000,45000,1) for ages in range(11)]
devs=sorted(dev,reverse=False)
print("Unsorted",dev)
print("Sorted",devs)
# Out:
# Unsorted [31539, 34785, 39802, 44666, 42161, 37550, 42595, 43747, 34883, 30719, 37285]
# Sorted [30719, 31539, 34785, 34883, 37285, 37550, 39802, 42161, 42595, 43747, 44666]

# %% [markdown]
# PLotting the Line Graph

# %%
plt.plot(ages,devs)
plt.xlabel("Age")
plt.ylabel("Salary in $")
plt.show()

# %%
py_dev=[random.randrange(50000,75000,1) for ages in range(11)]
py_devs=sorted(py_dev,reverse=False)

# %% [markdown]
# Plotting the Graph

# %%
plt.plot(ages,devs,label="All Developers")
plt.plot(ages,py_devs,label="Python Developers")
plt.xlabel("Age")
plt.ylabel("Salary in $")
plt.legend()
plt.show()
